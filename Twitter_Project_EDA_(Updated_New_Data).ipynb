# %%
#Import Libraries
from collections import Counter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.corpus import stopwords
import string
import plotly.express as px
import re
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('stopwords')
nltk.download('vader_lexicon')

# !pip install unidecode
import unidecode
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# Collecting unidecode
#   Downloading Unidecode-1.3.2-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 7.1 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.2

# %%
from nltk.stem import WordNetLemmatizer 
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
nltk.download('punkt')
from nltk.tokenize import word_tokenize 
import matplotlib.animation as animation
import operator
from collections import Counter

def dfCleaning(df):

    #import pandas_profiling

    #df = df[['text','retweet_count','favorite_count']]
    df.drop_duplicates(inplace = True)
    #Lowercase
    df['clean_tweet']= df['text'].apply(lambda x : x.lower())
    #Code to remove https
    df['clean_tweet'] = df['clean_tweet'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])
    #Code to remove @
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join([tweet for tweet in x.split()if not tweet.startswith("@")]))
    #Removing numbers
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join([tweet for tweet in x.split() if not tweet == '\d*']))
    #Removing all the greek characters using unidecode library
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join([unidecode.unidecode(word) for word in x.split()])) 
    #Removing the word 'hmm' and it's variants
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join([word for word in x.split() if not word == 'h(m)+' ]))
    #Code for removing slang words
    d = {'luv':'love','wud':'would','lyk':'like','wateva':'whatever','ttyl':'talk to you later',
                   'kul':'cool','fyn':'fine','omg':'oh my god!','fam':'family','bruh':'brother',
                   'cud':'could','fud':'food','gal':'girl'} ## Need a huge dictionary
    words = "I luv myself"
    words = words.split()
    reformed = [d[word] if word in d else word for word in words]
    reformed = " ".join(reformed)
    
    df['clean_tweet'] = df['clean_tweet'].apply(
        lambda x : ' '.join(d[word] if word in d else word for word in x.split()))
    
    #Finding words with # attached to it
    df['#'] = df['clean_tweet'].apply(
        lambda x : ' '.join([word for word in x.split() if word.startswith('#')]))
    frame = df['#']
    frame = pd.DataFrame(frame)
    frame = frame.rename({'#':'Count(#)'},axis = 'columns')
    frame[frame['Count(#)'] == ''] = 'No hashtags'
    data_frame = pd.concat([df,frame],axis = 1)
    data_frame.drop('#',axis = 1,inplace = True)
    
    #Column showing whether the corresponding tweet has a hash tagged word or not
    data_frame = data_frame.rename({'Count(#)':'Hash words'},axis = 'columns')

    #Removing stopwords
    data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(
        lambda x : ' '.join([word for word in x.split() 
                             if word not in set(stopwords.words('english')) and len(word) > 3]))
    #Lemmatization
    lemmatizer = WordNetLemmatizer()
    #data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(lambda x : ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))
    wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
    data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(
        lambda x : ' '.join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in nltk.pos_tag(x.split())]))

    #Code to remove punctuation
    data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(lambda x : re.sub('[%s]' % re.escape(string.punctuation),'',str(x)))
    
    #Stemming
    #ps = PorterStemmer()
    #adwait = data_frame
    #data_frame['clean_tweet'] = data_frame['clean_tweet'].apply(lambda x : ' '.join([ps.stem(word) for word in x.split()]))
    #reset index
    data_frame.reset_index(drop=True, inplace=True)
        
    return data_frame
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#Load EU data
data_path ="https://docs.google.com/spreadsheets/d/e/2PACX-1vS2YUVs3KiWrlRwhB5lChvWFcXohM2rCadmPQ6o9M8xqVVuyR8get446v5S8aLMTFyPbgelgoZpfJZK/pub?output=csv"
EU_df = pd.read_csv(data_path)
EU_df.shape
# Out:
# (1878, 151)

# %%
#Load NA data
data_path ="https://docs.google.com/spreadsheets/d/e/2PACX-1vShLH35WobPiO9SfKXExN_DTiW7iiBMM1zWJ5rFAJXKaaqvMlSLUqhdlIvDFByy7kayfpZ1LbrMq--0/pub?output=csv"
NA_df = pd.read_csv(data_path)
NA_df.shape
# Out:
# (626, 149)

# %%
#Load Asia data
data_path ="https://docs.google.com/spreadsheets/d/e/2PACX-1vRmG40vTMYS1mYPBZoYl0ZvEAQOShKEiT0pCS90Pxk7K6pzKUPDEHtt6FvpJ5TJOATJTSw7quKs9_IW/pub?output=csv"
AS_df = pd.read_csv(data_path)
AS_df.shape
# Out:
# (106, 153)

# %%
#Load India data
data_path ="https://docs.google.com/spreadsheets/d/e/2PACX-1vRzAc7Qjdm30l52Z3HwxOXemjXYYvRYNgloyVlXO_JP07PtxjwGJj56dt4Hvk6gCkvn0vAF5GxyH1wQ/pub?output=csv"
IN_df = pd.read_csv(data_path)
IN_df.shape
# Out:
# (309, 153)

# %% [markdown]
# **Europe Data**

# %%
EU_df.info()
EU_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1878 entries, 0 to 1877
# Columns: 151 entries, _id to user.withheld_in_countries
# dtypes: bool(18), float64(37), int64(9), object(87)
# memory usage: 1.9+ MB
#                         _id  ...  user.withheld_in_countries
# 0  61edc79d9130aa71fc8397a7  ...                          []
# 1  61edc79d9130aa71fc8397a8  ...                          []
# 2  61edc79d9130aa71fc8397a9  ...                          []
# 3  61edc79d9130aa71fc8397aa  ...                          []
# 4  61edc79e9130aa71fc8397ab  ...                          []
#
# [5 rows x 151 columns]

# %%
EU_tweets = EU_df[['text','retweet_count','favorite_count']]

# %%
#Data cleaning
EU_Cleaned = dfCleaning(EU_tweets)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
EU_Cleaned.head()
# Out:
#                                                 text  ...   Hash words
# 0  A women’s support group chooses not to signpos...  ...  No hashtags
# 1  You know the worst thing about the hate incide...  ...  No hashtags
# 2  @GeorgeHotchki14 @HJoyceGender @amscanlon Yup,...  ...  No hashtags
# 3  @peacelove1967 @ScotCuthbertson Started report...  ...  No hashtags
# 4  @peacelove1967 @ScotCuthbertson You talk of mu...  ...  No hashtags
#
# [5 rows x 5 columns]

# %% [markdown]
# **North America Data**

# %%
NA_tweets = NA_df[['text','retweet_count','favorite_count']]

# %%
NA_Cleaned = dfCleaning(NA_tweets)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
NA_Cleaned.head()
# Out:
#                                                 text  ...   Hash words
# 0  @TheRevAl @TheRevAl @MeetThePress @FaceTheNati...  ...  No hashtags
# 1  @nathaliejacoby1 the legal punishment will not...  ...  No hashtags
# 2  Cooper Kupp out there cookin Niggas  like its ...  ...  No hashtags
# 3  @angry_gammy @thatdaneshguy Absolutely its a h...  ...  No hashtags
# 4  @PR_NHL What about racism to white people, we ...  ...  No hashtags
#
# [5 rows x 5 columns]

# %% [markdown]
# **Asia Data**

# %%
AS_tweets = AS_df[['text','retweet_count','favorite_count']]

# %%
AS_Cleaned = dfCleaning(AS_tweets)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
AS_Cleaned.head()
# Out:
#                                                 text  ...   Hash words
# 0  District attorney of Connecticut: James be cha...  ...  No hashtags
# 1  @hongerootooties this is a hate crime cc: @ril...  ...  No hashtags
# 2  @k_athanasi @FrankPallone Your tweet is a HATE...  ...  No hashtags
# 3       This is a hate crime https://t.co/Zzfvrvjmft  ...  No hashtags
# 4                @legendaryadkins this is hate crime  ...  No hashtags
#
# [5 rows x 5 columns]

# %% [markdown]
# **India Data**

# %%
IN_tweets = IN_df[['text','retweet_count','favorite_count']]

# %%
IN_Cleaned = dfCleaning(IN_tweets)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
IN_Cleaned.head()
# Out:
#                                                 text  ...   Hash words
# 0  @Hate_Congress @AminaaKausar Death sentence fo...  ...  No hashtags
# 1  @Hate_Congress @AminaaKausar Crime is crime . ...  ...  No hashtags
# 2  @DiwakarSharmaa @ShivRajMathur1 Now they are a...  ...  No hashtags
# 3  I hate this bitch, she'll befriend u, turn u t...  ...  No hashtags
# 4  @FaissalFarooq @Nidhi What these guys ve alleg...  ...  No hashtags
#
# [5 rows x 5 columns]

# %% [markdown]
# **EDA**

# %% [markdown]
# *Tweet Count*

# %%
#count the total tweets of each dataframe
dataframes = {'Europe': EU_Cleaned, 'North America': NA_Cleaned, 'Asia': AS_Cleaned, 'India': IN_Cleaned}
df_region = pd.DataFrame([(i, df.shape[0]) for i, df in dataframes.items()],
                            columns=['df','count_rows'])

#tweets for each region_plot
fig, ax = plt.subplots(figsize=(12,8))

labels = df_region['df']
colors = sns.color_palette("Greens")

ax.pie(df_region['count_rows'], labels=labels, colors=colors, autopct='%.1f%%',
       wedgeprops={'linewidth': 2.0, 'edgecolor': 'white'},
       textprops={'size': 'x-large'})
ax.set_title('% of Tweets for each region', fontsize=14)

plt.show()

# %% [markdown]
# *Retweet Count*

# %%
#retweet_count plots
fig, axs = plt.subplots(1,4, figsize=(25,9))

ax1=sns.countplot(x='retweet_count', data=EU_Cleaned, ax=axs[0])
ax1.set(title='Europe')
ax1.set_xlim([0, 25])

ax2=sns.countplot(x='retweet_count', data=NA_Cleaned, ax=axs[1])
ax2.set(title='North America')
ax2.set_xlim([0, 25])

ax3=sns.countplot(x='retweet_count', data=AS_Cleaned, ax=axs[2])
ax3.set(title='Asia')
ax3.set_xlim([0, 25])

ax4=sns.countplot(x='retweet_count', data=IN_Cleaned, ax=axs[3])
ax4.set(title='India')
ax4.set_xlim([0, 25])

plt.show()

# %% [markdown]
# *Favorite Count*

# %%
#favorite_count plots
fig, axs = plt.subplots(1,4, figsize=(25,9))

ax1=sns.countplot(x='favorite_count', data=EU_Cleaned, ax=axs[0])
ax1.set(title='Europe')
ax1.set_xlim([0, 25])

ax2=sns.countplot(x='favorite_count', data=NA_Cleaned, ax=axs[1])
ax2.set(title='North America')
ax2.set_xlim([0, 25])

ax3=sns.countplot(x='favorite_count', data=AS_Cleaned, ax=axs[2])
ax3.set(title='Asia')
ax3.set_xlim([0, 25])

ax4=sns.countplot(x='favorite_count', data=IN_Cleaned, ax=axs[3])
ax4.set(title='India')
ax4.set_xlim([0, 25])

plt.show()

# %% [markdown]
# **Most Common Words**

# %% [markdown]
# *EU*

# %%
#Most common words
EU_Cleaned['temp_list'] = EU_Cleaned['clean_tweet'].apply(lambda x:str(x).split())
top = Counter([item for sublist in EU_Cleaned['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
# #T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row0_col1{
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row1_col1{
#             background-color:  #481084;
#             color:  #f1f1f1;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row2_col1{
#             background-color:  #dadaeb;
#             color:  #000000;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row3_col1{
#             background-color:  #e9e8f2;
#             color:  #000000;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row4_col1{
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row5_col1{
#             background-color:  #f4f2f8;
#             color:  #000000;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row6_col1{
#             background-color:  #f7f5fa;
#             color:  #000000;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row7_col1,#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row8_col1{
#             background-color:  #f8f7fa;
#             color:  #000000;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row9_col1{
#             background-color:  #f8f7fb;
#             color:  #000000;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row10_col1,#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row11_col1{
#             background-color:  #faf9fc;
#             color:  #000000;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row12_col1,#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row13_col1,#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row14_col1,#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row15_col1{
#             background-color:  #fbfafc;
#             color:  #000000;
#         }#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row16_col1,#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row17_col1,#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row18_col1,#T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row19_col1{
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row0_col0" class="data row0 col0" >hate</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row0_col1" class="data row0 col1" >1425</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row1_col0" class="data row1 col0" >crime</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row1_col1" class="data row1 col1" >1353</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row2_col0" class="data row2 col0" >misogyny</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row2_col1" class="data row2 col1" >399</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row3_col0" class="data row3 col0" >make</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row3_col1" class="data row3 col1" >277</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row4_col0" class="data row4 col0" >lord</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row4_col1" class="data row4 col1" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row5_col0" class="data row5 col0" >vote</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row5_col1" class="data row5 col1" >166</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row6_col0" class="data row6 col0" >report</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row6_col1" class="data row6 col1" >125</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row7_col0" class="data row7 col0" >defeat</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row7_col1" class="data row7 col1" >110</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row8_col0" class="data row8 col0" >police</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row8_col1" class="data row8 col1" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row9_col0" class="data row9 col0" >people</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row9_col1" class="data row9 col1" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row10_col0" class="data row10 col0" >house</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row10_col1" class="data row10 col1" >79</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row11_col0" class="data row11 col0" >would</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row11_col1" class="data row11 col1" >79</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row12_col0" class="data row12 col0" >woman</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row12_col1" class="data row12 col1" >76</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row13_col0" class="data row13 col0" >like</td>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row13_col1" class="data row13 col1" >76</td>
#             </tr>
#             <tr>
#                         <th id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_1f8c7e58_818b_11ec_baf7_0242ac1c0002row14_col0" class="data row14 col0" >government</td>
#                         <td id="T

# %%
#Bar plot for most common words
plt.figure(figsize=(12,8))
sns.barplot(y='Common_words', x='count', data=temp)

# %% [markdown]
# *NA*

# %%
#Most common words
NA_Cleaned['temp_list'] = NA_Cleaned['clean_tweet'].apply(lambda x:str(x).split())
top = Counter([item for sublist in NA_Cleaned['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
# #T_2382a212_818b_11ec_baf7_0242ac1c0002row0_col1{
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }#T_2382a212_818b_11ec_baf7_0242ac1c0002row1_col1{
#             background-color:  #41047f;
#             color:  #f1f1f1;
#         }#T_2382a212_818b_11ec_baf7_0242ac1c0002row2_col1{
#             background-color:  #f6f5f9;
#             color:  #000000;
#         }#T_2382a212_818b_11ec_baf7_0242ac1c0002row3_col1{
#             background-color:  #f7f5fa;
#             color:  #000000;
#         }#T_2382a212_818b_11ec_baf7_0242ac1c0002row4_col1{
#             background-color:  #f8f6fa;
#             color:  #000000;
#         }#T_2382a212_818b_11ec_baf7_0242ac1c0002row5_col1{
#             background-color:  #f9f7fb;
#             color:  #000000;
#         }#T_2382a212_818b_11ec_baf7_0242ac1c0002row6_col1{
#             background-color:  #f9f8fb;
#             color:  #000000;
#         }#T_2382a212_818b_11ec_baf7_0242ac1c0002row7_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row8_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row9_col1{
#             background-color:  #faf9fc;
#             color:  #000000;
#         }#T_2382a212_818b_11ec_baf7_0242ac1c0002row10_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row11_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row12_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row13_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row14_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row15_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row16_col1{
#             background-color:  #fbfafc;
#             color:  #000000;
#         }#T_2382a212_818b_11ec_baf7_0242ac1c0002row17_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row18_col1,#T_2382a212_818b_11ec_baf7_0242ac1c0002row19_col1{
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_2382a212_818b_11ec_baf7_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row0_col0" class="data row0 col0" >crime</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row0_col1" class="data row0 col1" >408</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row1_col0" class="data row1 col0" >hate</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row1_col1" class="data row1 col1" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row2_col0" class="data row2 col0" >asian</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row2_col1" class="data row2 col1" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row3_col0" class="data row3 col0" >like</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row3_col1" class="data row3 col1" >41</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row4_col0" class="data row4 col0" >woman</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row4_col1" class="data row4 col1" >38</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row5_col0" class="data row5 col0" >charge</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row5_col1" class="data row5 col1" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row6_col0" class="data row6 col0" >attack</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row6_col1" class="data row6 col1" >32</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row7_col0" class="data row7 col0" >call</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row7_col1" class="data row7 col1" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row8_col0" class="data row8 col0" >hostage</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row8_col1" class="data row8 col1" >29</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row9_col0" class="data row9 col0" >people</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row9_col1" class="data row9 col1" >28</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row10_col0" class="data row10 col0" >black</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row10_col1" class="data row10 col1" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row11_col0" class="data row11 col0" >texas</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row11_col1" class="data row11 col1" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row12_col0" class="data row12 col0" >synagogue</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row12_col1" class="data row12 col1" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row13_col0" class="data row13 col0" >say</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row13_col1" class="data row13 col1" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_baf7_0242ac1c0002level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row14_col0" class="data row14 col0" >jewish</td>
#                         <td id="T_2382a212_818b_11ec_baf7_0242ac1c0002row14_col1" class="data row14 col1" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_2382a212_818b_11ec_

# %%
#Bar plot for most common words
plt.figure(figsize=(12,8))
sns.barplot(y='Common_words', x='count', data=temp)

# %% [markdown]
# *AS*

# %%
#Most common words
AS_Cleaned['temp_list'] = AS_Cleaned['clean_tweet'].apply(lambda x:str(x).split())
top = Counter([item for sublist in AS_Cleaned['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
# #T_50f17908_818b_11ec_baf7_0242ac1c0002row0_col1{
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }#T_50f17908_818b_11ec_baf7_0242ac1c0002row1_col1{
#             background-color:  #491285;
#             color:  #f1f1f1;
#         }#T_50f17908_818b_11ec_baf7_0242ac1c0002row2_col1{
#             background-color:  #e7e6f1;
#             color:  #000000;
#         }#T_50f17908_818b_11ec_baf7_0242ac1c0002row3_col1{
#             background-color:  #f5f3f8;
#             color:  #000000;
#         }#T_50f17908_818b_11ec_baf7_0242ac1c0002row4_col1{
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }#T_50f17908_818b_11ec_baf7_0242ac1c0002row5_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row6_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row7_col1{
#             background-color:  #f8f7fb;
#             color:  #000000;
#         }#T_50f17908_818b_11ec_baf7_0242ac1c0002row8_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row9_col1{
#             background-color:  #faf8fb;
#             color:  #000000;
#         }#T_50f17908_818b_11ec_baf7_0242ac1c0002row10_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row11_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row12_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row13_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row14_col1{
#             background-color:  #fbfafc;
#             color:  #000000;
#         }#T_50f17908_818b_11ec_baf7_0242ac1c0002row15_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row16_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row17_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row18_col1,#T_50f17908_818b_11ec_baf7_0242ac1c0002row19_col1{
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_50f17908_818b_11ec_baf7_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row0_col0" class="data row0 col0" >hate</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row0_col1" class="data row0 col1" >84</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row1_col0" class="data row1 col0" >crime</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row1_col1" class="data row1 col1" >79</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row2_col0" class="data row2 col0" >asian</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row2_col1" class="data row2 col1" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row3_col0" class="data row3 col0" >people</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row3_col1" class="data row3 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row4_col0" class="data row4 col0" >make</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row4_col1" class="data row4 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row5_col0" class="data row5 col0" >stop</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row5_col1" class="data row5 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row6_col0" class="data row6 col0" >commit</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row7_col0" class="data row7 col0" >black</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row7_col1" class="data row7 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row8_col0" class="data row8 col0" >like</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row8_col1" class="data row8 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row9_col0" class="data row9 col0" >know</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row9_col1" class="data row9 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row10_col0" class="data row10 col0" >take</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row10_col1" class="data row10 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row11_col0" class="data row11 col0" >problem</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row11_col1" class="data row11 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row12_col0" class="data row12 col0" >victim</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row12_col1" class="data row12 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row13_col0" class="data row13 col0" >chinese</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row13_col1" class="data row13 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row14_col0" class="data row14 col0" >white</td>
#                         <td id="T_50f17908_818b_11ec_baf7_0242ac1c0002row14_col1" class="data row14 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50f17908_818b_11ec_baf7_0242ac1c0002level0_row15" class="row_heading level0 row15" >15</th>

# %%
#Bar plot for most common words
plt.figure(figsize=(12,8))
sns.barplot(y='Common_words', x='count', data=temp)

# %% [markdown]
# *IN*

# %%
#Most common words
IN_Cleaned['temp_list'] = IN_Cleaned['clean_tweet'].apply(lambda x:str(x).split())
top = Counter([item for sublist in IN_Cleaned['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
# #T_776e411a_818b_11ec_baf7_0242ac1c0002row0_col1{
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row1_col1{
#             background-color:  #420680;
#             color:  #f1f1f1;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row2_col1{
#             background-color:  #f0eef5;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row3_col1{
#             background-color:  #f3f2f8;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row4_col1,#T_776e411a_818b_11ec_baf7_0242ac1c0002row5_col1{
#             background-color:  #f5f3f8;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row6_col1,#T_776e411a_818b_11ec_baf7_0242ac1c0002row7_col1{
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row8_col1{
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row9_col1{
#             background-color:  #f8f7fa;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row10_col1{
#             background-color:  #f9f7fb;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row11_col1{
#             background-color:  #faf8fb;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row12_col1{
#             background-color:  #faf9fc;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row13_col1,#T_776e411a_818b_11ec_baf7_0242ac1c0002row14_col1,#T_776e411a_818b_11ec_baf7_0242ac1c0002row15_col1,#T_776e411a_818b_11ec_baf7_0242ac1c0002row16_col1{
#             background-color:  #fbfafc;
#             color:  #000000;
#         }#T_776e411a_818b_11ec_baf7_0242ac1c0002row17_col1,#T_776e411a_818b_11ec_baf7_0242ac1c0002row18_col1,#T_776e411a_818b_11ec_baf7_0242ac1c0002row19_col1{
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_776e411a_818b_11ec_baf7_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row0_col0" class="data row0 col0" >hate</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row0_col1" class="data row0 col1" >213</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row1_col0" class="data row1 col0" >crime</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row1_col1" class="data row1 col1" >209</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row2_col0" class="data row2 col0" >sikh</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row2_col1" class="data row2 col1" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row3_col0" class="data row3 col0" >make</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row3_col1" class="data row3 col1" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row4_col0" class="data row4 col0" >taxi</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row4_col1" class="data row4 col1" >25</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row5_col0" class="data row5 col0" >driver</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row5_col1" class="data row5 col1" >25</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row6_col0" class="data row6 col0" >arrest</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row6_col1" class="data row6 col1" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row7_col0" class="data row7 col0" >attack</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row7_col1" class="data row7 col1" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row8_col0" class="data row8 col0" >muslim</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row8_col1" class="data row8 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row9_col0" class="data row9 col0" >charge</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row9_col1" class="data row9 col1" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row10_col0" class="data row10 col0" >misogyny</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row10_col1" class="data row10 col1" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row11_col0" class="data row11 col0" >police</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row11_col1" class="data row11 col1" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row12_col0" class="data row12 col0" >speech</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row12_col1" class="data row12 col1" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row13_col0" class="data row13 col0" >hindu</td>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row13_col1" class="data row13 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_776e411a_818b_11ec_baf7_0242ac1c0002level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_776e411a_818b_11ec_baf7_0242ac1c0002row14_col0" c

# %%
#Bar plot for most common words
plt.figure(figsize=(12,8))
sns.barplot(y='Common_words', x='count', data=temp)

# %% [markdown]
# **Wordclouds**

# %%
def my_tf_color_func(dictionary):
  def my_tf_color_func_inner(word, **kwargs):
    return "hsl(%d, 80%%, 50%%)" % (360 * dictionary[word])
  return my_tf_color_func_inner

# %% [markdown]
# *EU*

# %%
normal_words = ' '.join([word for word in EU_Cleaned['clean_tweet']])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(normal_words)
print('Normal words')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# Normal words
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# EU Hashtags

# %%
hashtags = ' '.join([word for word in EU_Cleaned['Hash words'].unique()])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "black").generate(hashtags)
print('hashtags')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear', cmap='Set2')
plt.axis('off')
# Out:
# hashtags
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# *NA*

# %%
normal_words = ' '.join([word for word in NA_Cleaned['clean_tweet']])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(normal_words)
print('Normal words')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# Normal words
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# NA Hashtags

# %%
hashtags = ' '.join([word for word in NA_Cleaned['Hash words'].unique()])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "black").generate(hashtags)
print('hashtags')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='Set2')
plt.axis('off')
# Out:
# hashtags
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# *AS*

# %%
normal_words = ' '.join([word for word in AS_Cleaned['clean_tweet']])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(normal_words)
print('Normal words')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# Normal words
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# AS Hashtags

# %%
hashtags = ' '.join([word for word in AS_Cleaned['Hash words'].unique()])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "black").generate(hashtags)
print('hashtags')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='Set2')
plt.axis('off')
# Out:
# hashtags
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# *IN*

# %%
normal_words = ' '.join([word for word in IN_Cleaned['clean_tweet']])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "white").generate(normal_words)
print('Normal words')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='viridis')
plt.axis('off')
# Out:
# Normal words
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# IN Hashtags

# %%
hashtags = ' '.join([word for word in IN_Cleaned['Hash words'].unique()])
wordcloud = WordCloud(width = 800, height = 500, max_font_size = 110,max_words = 75,background_color = "black").generate(hashtags)
print('hashtags')
plt.figure(figsize= (12,8))
plt.imshow(wordcloud, interpolation = 'bilinear',cmap='Set2')
plt.axis('off')
# Out:
# hashtags
# (-0.5, 799.5, 499.5, -0.5)

# %% [markdown]
# **Vader Sentiment Analysis**
# - polarity
# - subjectivity
# - neg, neu, pos scores
# - compound
# -sentiment

# %% [markdown]
# *Europe*

# %%
#Europe
sia = SentimentIntensityAnalyzer()
EU_Cleaned[['polarity', 'subjectivity']] = EU_Cleaned['clean_tweet'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, s in enumerate(EU_Cleaned['text']):
  ps = sia.polarity_scores(s)
  EU_Cleaned.loc[index,['neg']] = ps['neg']
  EU_Cleaned.loc[index,['neu']] = ps['neu']
  EU_Cleaned.loc[index,['pos']] = ps['pos']
  EU_Cleaned.loc[index,['compound']] = ps['compound']
  if ps['neg'] > ps['pos']:
    EU_Cleaned.loc[index,['sentiment']] = 'negative'
  elif ps['pos'] > ps['neg']:
    EU_Cleaned.loc[index,['sentiment']] = 'positive'
  else:
    EU_Cleaned.loc[index,['sentiment']] = 'neutral'
   
EU_Cleaned.head(10)
# Out:
#                                                 text  ...  sentiment
# 0  A women’s support group chooses not to signpos...  ...   negative
# 1  You know the worst thing about the hate incide...  ...   negative
# 2  @GeorgeHotchki14 @HJoyceGender @amscanlon Yup,...  ...   negative
# 3  @peacelove1967 @ScotCuthbertson Started report...  ...   positive
# 4  @peacelove1967 @ScotCuthbertson You talk of mu...  ...   negative
# 5  @AntisemitismEye @NoughtFollowers @ayeshahazar...  ...    neutral
# 6  @HJoyceGender @amscanlon Reporting this as a h...  ...   negative
# 7  Awful news that a gay man has been the victim ...  ...   negative
# 8  The transphobes don’t care about the soaring h...  ...   negative
# 9  @FootyBevs @FootyScran @ManUtd This is a hate ...  ...   negative
#
# [10 rows x 13 columns]

# %%
#EU Histograms of polarity and subjectivity
n_bins = 50
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18,7))
ax1.hist(EU_Cleaned["polarity"], bins = n_bins)
ax1.set_title('EU Polarity Scores')
ax2.hist(EU_Cleaned["subjectivity"], bins = n_bins)
ax2.set_title('EU Subjectivity Scores')
plt.show()

# %%
#EU Countplot of sentiment
sns.set(rc={'figure.figsize':(10,7)})
ax = sns.countplot(x="sentiment", data=EU_Cleaned)
ax.set(xlabel='Europe Sentiment Result')
# Out:
# [Text(0.5, 0, 'Europe Sentiment Result')]

# %% [markdown]
# *North Amercia*

# %%
#North America
sia = SentimentIntensityAnalyzer()
NA_Cleaned[['polarity', 'subjectivity']] = NA_Cleaned['clean_tweet'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, s in enumerate(NA_Cleaned['text']):
  ps = sia.polarity_scores(s)
  NA_Cleaned.loc[index,['neg']] = ps['neg']
  NA_Cleaned.loc[index,['neu']] = ps['neu']
  NA_Cleaned.loc[index,['pos']] = ps['pos']
  NA_Cleaned.loc[index,['compound']] = ps['compound']
  if ps['neg'] > ps['pos']:
    NA_Cleaned.loc[index,['sentiment']] = 'negative'
  elif ps['pos'] > ps['neg']:
    NA_Cleaned.loc[index,['sentiment']] = 'positive'
  else:
    NA_Cleaned.loc[index,['sentiment']] = 'neutral'
   
NA_Cleaned.head()
# Out:
#                                                 text  ...  sentiment
# 0  @TheRevAl @TheRevAl @MeetThePress @FaceTheNati...  ...    neutral
# 1  @nathaliejacoby1 the legal punishment will not...  ...   negative
# 2  Cooper Kupp out there cookin Niggas  like its ...  ...   negative
# 3  @angry_gammy @thatdaneshguy Absolutely its a h...  ...   negative
# 4  @PR_NHL What about racism to white people, we ...  ...   negative
#
# [5 rows x 13 columns]

# %%
#NA Histograms of polarity and subjectivity
n_bins = 50
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18,7))
ax1.hist(NA_Cleaned["polarity"], bins = n_bins)
ax1.set_title('NA Polarity Scores')
ax2.hist(NA_Cleaned["subjectivity"], bins = n_bins)
ax2.set_title('NA Subjectivity Scores')
plt.show()

# %%
#NA Countplot of sentiment
sns.set(rc={'figure.figsize':(10,7)})
ax = sns.countplot(x="sentiment", data=NA_Cleaned)
ax.set(xlabel='North America Sentiment Result')
# Out:
# [Text(0.5, 0, 'North America Sentiment Result')]

# %% [markdown]
# *Asia*

# %%
#Asia
sia = SentimentIntensityAnalyzer()
AS_Cleaned[['polarity', 'subjectivity']] = AS_Cleaned['clean_tweet'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, s in enumerate(AS_Cleaned['text']):
  ps = sia.polarity_scores(s)
  AS_Cleaned.loc[index,['neg']] = ps['neg']
  AS_Cleaned.loc[index,['neu']] = ps['neu']
  AS_Cleaned.loc[index,['pos']] = ps['pos']
  AS_Cleaned.loc[index,['compound']] = ps['compound']
  if ps['neg'] > ps['pos']:
    AS_Cleaned.loc[index,['sentiment']] = 'negative'
  elif ps['pos'] > ps['neg']:
    AS_Cleaned.loc[index,['sentiment']] = 'positive'
  else:
    AS_Cleaned.loc[index,['sentiment']] = 'neutral'
   
AS_Cleaned.head()
# Out:
#                                                 text  ...  sentiment
# 0  District attorney of Connecticut: James be cha...  ...   negative
# 1  @hongerootooties this is a hate crime cc: @ril...  ...   negative
# 2  @k_athanasi @FrankPallone Your tweet is a HATE...  ...   negative
# 3       This is a hate crime https://t.co/Zzfvrvjmft  ...   negative
# 4                @legendaryadkins this is hate crime  ...   negative
#
# [5 rows x 13 columns]

# %%
#AS Histograms of polarity and subjectivity
n_bins = 50
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18,7))
ax1.hist(AS_Cleaned["polarity"], bins = n_bins)
ax1.set_title('AS Polarity Scores')
ax2.hist(AS_Cleaned["subjectivity"], bins = n_bins)
ax2.set_title('AS Subjectivity Scores')
plt.show()

# %%
#AS Countplot of sentiment
sns.set(rc={'figure.figsize':(10,7)})
ax = sns.countplot(x="sentiment", data=AS_Cleaned)
ax.set(xlabel='Asia Sentiment Result')
# Out:
# [Text(0.5, 0, 'Asia Sentiment Result')]

# %% [markdown]
# *India*

# %%
#India
sia = SentimentIntensityAnalyzer()
IN_Cleaned[['polarity', 'subjectivity']] = IN_Cleaned['clean_tweet'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, s in enumerate(IN_Cleaned['text']):
  ps = sia.polarity_scores(s)
  IN_Cleaned.loc[index,['neg']] = ps['neg']
  IN_Cleaned.loc[index,['neu']] = ps['neu']
  IN_Cleaned.loc[index,['pos']] = ps['pos']
  IN_Cleaned.loc[index,['compound']] = ps['compound']
  if ps['neg'] > ps['pos']:
    IN_Cleaned.loc[index,['sentiment']] = 'negative'
  elif ps['pos'] > ps['neg']:
    IN_Cleaned.loc[index,['sentiment']] = 'positive'
  else:
    IN_Cleaned.loc[index,['sentiment']] = 'neutral'
   
IN_Cleaned.head()
# Out:
#                                                 text  ...  sentiment
# 0  @Hate_Congress @AminaaKausar Death sentence fo...  ...   negative
# 1  @Hate_Congress @AminaaKausar Crime is crime . ...  ...   negative
# 2  @DiwakarSharmaa @ShivRajMathur1 Now they are a...  ...   negative
# 3  I hate this bitch, she'll befriend u, turn u t...  ...   negative
# 4  @FaissalFarooq @Nidhi What these guys ve alleg...  ...   negative
#
# [5 rows x 13 columns]

# %%
#IN Histograms of polarity and subjectivity
n_bins = 50
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18,7))
ax1.hist(IN_Cleaned["polarity"], bins = n_bins)
ax1.set_title('IN Polarity Scores')
ax2.hist(IN_Cleaned["subjectivity"], bins = n_bins)
ax2.set_title('IN Subjectivity Scores')
plt.show()

# %%
#IN Countplot of sentiment
sns.set(rc={'figure.figsize':(10,7)})
ax = sns.countplot(x="sentiment", data=IN_Cleaned)
ax.set(xlabel='India Sentiment Result')
# Out:
# [Text(0.5, 0, 'India Sentiment Result')]

# %%
EU_Cleaned['region'] ='Europe'
NA_Cleaned['region'] ='North America'
AS_Cleaned['region'] ='Asia'
IN_Cleaned['region'] ='India'

# %%
#Concat regions into the same dataframe
frames = [EU_Cleaned, NA_Cleaned, AS_Cleaned, IN_Cleaned]
  
combine_df = pd.concat(frames)
display(combine_df)
# Out:
#                                                   text  ...  region
# 0    A women’s support group chooses not to signpos...  ...  Europe
# 1    You know the worst thing about the hate incide...  ...  Europe
# 2    @GeorgeHotchki14 @HJoyceGender @amscanlon Yup,...  ...  Europe
# 3    @peacelove1967 @ScotCuthbertson Started report...  ...  Europe
# 4    @peacelove1967 @ScotCuthbertson You talk of mu...  ...  Europe
# ..                                                 ...  ...     ...
# 302  @mmm_eat_glass @anumccartney This is a hate crime  ...   India
# 303  New Jersey Police arrests Mohamed Hassanain in...  ...   India
# 304  New Jersey Police arrests Mohamed Hassanain in...  ...   India
# 305  @jahanzaib0126 @IndiaToday @gauravcsawant Indi...  ...   India
# 306  Indian Public mocks @gauravcsawant @IndiaToday...  ...   India
#
# [2918 rows x 14 columns]

# %% [markdown]
# ***Combined Graphs***

# %%
sns.set_style('ticks', rc={'figure.figsize':(10,15)})
ax = sns.countplot(x="sentiment", hue="region", data= combine_df)
ax.set_title('Sentiment Result Comparison',fontsize = 18, fontweight='bold' )
ax.set(xlabel='Sentiment')
#show count
for rect in ax.patches:
    ax.text (rect.get_x() + rect.get_width()  / 2,rect.get_height()+ 0.75,rect.get_height(),horizontalalignment='center', fontsize = 11)

# %%
#EU NA
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18,7))
ax1.hist(EU_Cleaned["polarity"], alpha=0.5, bins = n_bins, label="Europe")
ax1.hist(NA_Cleaned["polarity"], alpha=0.5, bins = n_bins, label="North America")
ax1.set_title("EUROPE and NORTH AMERICA Polarity Comparison", fontsize = 15, fontweight='bold')
ax1.set_xlabel("Score", size=14)
ax1.set_ylabel("Count", size=14)
ax1.legend(loc='upper right')

ax2.hist(EU_Cleaned["subjectivity"], alpha=0.5, bins = n_bins, label="Europe")
ax2.hist(NA_Cleaned["subjectivity"], alpha=0.5, bins = n_bins, label="North America")
ax2.set_title("EUROPE and NORTH AMERICA Subjectivity Comparison", fontsize = 15, fontweight='bold')
ax2.set_xlabel("Score", size=14)
ax2.set_ylabel("Count", size=14)
ax2.legend(loc='upper left')

# %%
#AS IN
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18,7))
ax1.hist(AS_Cleaned["polarity"], alpha=0.6, bins = n_bins, label="Asia", color='black')
ax1.hist(IN_Cleaned["polarity"], alpha=0.4, bins = n_bins, label="India", color='orange')
ax1.set_title("ASIA and INDIA Polarity Comparison", fontsize = 15, fontweight='bold')
ax1.set_xlabel("Score", size=14)
ax1.set_ylabel("Count", size=14)
ax1.legend(loc='upper right')

ax2.hist(AS_Cleaned["subjectivity"], alpha=0.6, bins = n_bins, label="Asia", color='black')
ax2.hist(IN_Cleaned["subjectivity"], alpha=0.4, bins = n_bins, label="India", color='orange')
ax2.set_title("ASIA and INDIA Subjectivity Comparison", fontsize = 15, fontweight='bold')
ax2.set_xlabel("Score", size=14)
ax2.set_ylabel("Count", size=14)
ax2.legend(loc='upper left')
